# %% [markdown]
# # Adding Non-Exercise Data to Database
#
# The already existing database for exercise data is used.

# %%
import sqlite3
import pandas as pd
import numpy as np
import os
import re
import functionsMasterProjectMeinhart as fmpm

# %% [markdown]
# ## Get the csv-file names of the non-exercise data (from a defined folder)

# %%
# folder with non-exercise csv-files
file_dir = 'E:\Physio_Data_Split_nonEx'

# load all file names of desired folder
nonEx_files = []
for (dirpath, dirnames, filenames) in os.walk(file_dir):
    nonEx_files.extend(filenames)
    break

nonEx_files
# Out:
# ['subject01_00_nonEx.csv',
#  'subject01_01_nonEx.csv',
#  'subject01_02_nonEx.csv',
#  'subject01_03_nonEx.csv',
#  'subject01_04_nonEx.csv',
#  'subject01_05_nonEx.csv',
#  'subject01_06_nonEx.csv',
#  'subject01_07_nonEx.csv',
#  'subject01_08_nonEx.csv',
#  'subject01_09_nonEx.csv',
#  'subject01_10_nonEx.csv',
#  'subject01_11_nonEx.csv',
#  'subject01_12_nonEx.csv',
#  'subject01_13_nonEx.csv',
#  'subject01_14_nonEx.csv',
#  'subject01_15_nonEx.csv',
#  'subject01_16_nonEx.csv',
#  'subject01_17_nonEx.csv',
#  'subject01_18_nonEx.csv',
#  'subject01_19_nonEx.csv',
#  'subject01_20_nonEx.csv',
#  'subject01_21_nonEx.csv',
#  'subject01_22_nonEx.csv',
#  'subject01_23_nonEx.csv',
#  'subject01_24_nonEx.csv',
#  'subject01_25_nonEx.csv',
#  'subject01_26_nonEx.csv',
#  'subject01_27_nonEx.csv',
#  'subject01_28_nonEx.csv',
#  'subject01_29_nonEx.csv',
#  'subject01_30_nonEx.csv',
#  'subject02_00_nonEx.csv',
#  'subject02_01_nonEx.csv',
#  'subject02_02_nonEx.csv',
#  'subject02_03_nonEx.csv',
#  'subject02_04_nonEx.csv',
#  'subject02_05_nonEx.csv',
#  'subject02_06_nonEx.csv',
#  'subject02_07_nonEx.csv',
#  'subject02_08_nonEx.csv',
#  'subject02_09_nonEx.csv',
#  'subject02_10_nonEx.csv',
#  'subject02_11_nonEx.csv',
#  'subject02_12_nonEx.csv',
#  'subject02_13_nonEx.csv',
#  'subject02_14_nonEx.csv',
#  'subject02_15_nonEx.csv',
#  'subject02_16_nonEx.csv',
#  'subject02_17_nonEx.csv',
#  'subject02_18_nonEx.csv',
#  'subject02_19_nonEx.csv',
#  'subject02_20_nonEx.csv',
#  'subject02_21_nonEx.csv',
#  'subject02_22_nonEx.csv',
#  'subject02_23_nonEx.csv',
#  'subject02_24_nonEx.csv',
#  'subject02_25_nonEx.csv',
#  'subject02_26_nonEx.csv',
#  'subject02_27_nonEx.csv',
#  'subject02_28_nonEx.csv',
#  'subject02_29_nonEx.csv',
#  'subject02_30_nonEx.csv',
#  'subject03_00_nonEx.csv',
#  'subject03_01_nonEx.csv',
#  'subject03_02_nonEx.csv',
#  'subject03_03_nonEx.csv',
#  'subject03_04_nonEx.csv',
#  'subject03_05_nonEx.csv',
#  'subject03_06_nonEx.csv',
#  'subject03_07_nonEx.csv',
#  'subject03_08_nonEx.csv',
#  'subject03_09_nonEx.csv',
#  'subject03_10_nonEx.csv',
#  'subject03_11_nonEx.csv',
#  'subject03_12_nonEx.csv',
#  'subject03_13_nonEx.csv',
#  'subject03_14_nonEx.csv',
#  'subject03_15_nonEx.csv',
#  'subject03_16_nonEx.csv',
#  'subject03_17_nonEx.csv',
#  'subject03_18_nonEx.csv',
#  'subject03_19_nonEx.csv',
#  'subject03_20_nonEx.csv',
#  'subject03_21_nonEx.csv',
#  'subject03_22_nonEx.csv',
#  'subject03_23_nonEx.csv',
#  'subject03_24_nonEx.csv',
#  'subject03_25_nonEx.csv',
#  'subject03_26_nonEx.csv',
#  'subject03_27_nonEx.csv',
#  'subject03_28_nonEx.csv',
#  'subject03_29_nonEx.csv',
#  'subject03_30_nonEx.csv',
#  'subject04_00_nonEx.csv',
#  'subject04_01_nonEx.csv',
#  'subject04_02_nonEx.csv',
#  'subject04_03_nonEx.csv',
#  'subject04_04_nonEx.csv',
#  'subject04_05_nonEx.csv',
#  'subject04_06_nonEx.csv',
#  'subject04_07_nonEx.csv',
#  'subject04_08_nonEx.csv',
#  'subject04_09_nonEx.csv',
#  'subject04_10_nonEx.csv',
#  'subject04_11_nonEx.csv',
#  'subject04_12_nonEx.csv',
#  'subject04_13_nonEx.csv',
#  'subject04_14_nonEx.csv',
#  'subject04_15_nonEx.csv',
#  'subject04_16_nonEx.csv',
#  'subject04_17_nonEx.csv',
#  'subject04_18_nonEx.csv',
#  'subject04_19_nonEx.csv',
#  'subject04_20_nonEx.csv',
#  'subject04_21_nonEx.csv',
#  'subject04_22_nonEx.csv',
#  'subject04_23_nonEx.csv',
#  'subject04_24_nonEx.csv',
#  'subject04_25_nonEx.csv',
#  'subject04_26_nonEx.csv',
#  'subject04_27_nonEx.csv',
#  'subject04_28_nonEx.csv',
#  'subject04_29_nonEx.csv',
#  'subject04_30_nonEx.csv',
#  'subject05_00_nonEx.csv',
#  'subject05_01_nonEx.csv',
#  'subject05_02_nonEx.csv',
#  'subject05_03_nonEx.csv',
#  'subject05_04_nonEx.csv',
#  'subject05_05_nonEx.csv',
#  'subject05_06_nonEx.csv',
#  'subject05_07_nonEx.csv',
#  'subject05_08_nonEx.csv',
#  'subject05_09_nonEx.csv',
#  'subject05_10_nonEx.csv',
#  'subject05_11_nonEx.csv',
#  'subject05_12_nonEx.csv',
#  'subject05_13_nonEx.csv',
#  'subject05_14_nonEx.csv',
#  'subject05_15_nonEx.csv',
#  'subject05_16_nonEx.csv',
#  'subject05_17_nonEx.csv',
#  'subject05_18_nonEx.csv',
#  'subject05_19_nonEx.csv',
#  'subject05_20_nonEx.csv',
#  'subject05_21_nonEx.csv',
#  'subject05_22_nonEx.csv',
#  'subject05_23_nonEx.csv',
#  'subject05_24_nonEx.csv',
#  'subject05_25_nonEx.csv',
#  'subject05_26_nonEx.csv',
#  'subject05_27_nonEx.csv',
#  'subject05_28_nonEx.csv',
#  'subject05_29_nonEx.csv',
#  'subject05_30_nonEx.csv',
#  'subject06_00_nonEx.csv',
#  'subject06_01_nonEx.csv',
#  'subject06_02_nonEx.csv',
#  'subject06_03_nonEx.csv',
#  'subject06_04_nonEx.csv',
#  'subject06_05_nonEx.csv',
#  'subject06_06_nonEx.csv',
#  'subject06_07_nonEx.csv',
#  'subject06_08_nonEx.csv',
#  'subject06_09_nonEx.csv',
#  'subject06_10_nonEx.csv',
#  'subject06_11_nonEx.csv',
#  'subject06_12_nonEx.csv',
#  'subject06_13_nonEx.csv',
#  'subject06_14_nonEx.csv',
#  'subject06_15_nonEx.csv',
#  'subject06_16_nonEx.csv',
#  'subject06_17_nonEx.csv',
#  'subject06_18_nonEx.csv',
#  'subject06_19_nonEx.csv',
#  'subject06_20_nonEx.csv',
#  'subject06_21_nonEx.csv',
#  'subject06_22_nonEx.csv',
#  'subject06_23_nonEx.csv',
#  'subject06_24_nonEx.csv',
#  'subject06_25_nonEx.csv',
#  'subject06_26_nonEx.csv',
#  'subject06_27_nonEx.csv',
#  'subject06_28_nonEx.csv',
#  'subject06_29_nonEx.csv',
#  'subject06_30_nonEx.csv',
#  'subject07_00_nonEx.csv',
#  'subject07_01_nonEx.csv',
#  'subject07_02_nonEx.csv',
#  'subject07_03_nonEx.csv',
#  'subject07_04_nonEx.csv',
#  'subject07_05_nonEx.csv',
#  'subject07_06_nonEx.csv',
#  'subject07_07_nonEx.csv',
#  'subject07_08_nonEx.csv',
#  'subject07_09_nonEx.csv',
#  'subject07_10_nonEx.csv',
#  'subject07_11_nonEx.csv',
#  'subject07_12_nonEx.csv',
#  'subject07_13_nonEx.csv',
#  'subject07_14_nonEx.csv',
#  'subject07_15_nonEx.csv',
#  'subject07_16_nonEx.csv',
#  'subject07_17_nonEx.csv',
#  'subject07_18_nonEx.csv',
#  'subject07_19_nonEx.csv',
#  'subject07_20_nonEx.csv',
#  'subject07_21_nonEx.csv',
#  'subject07_22_nonEx.csv',
#  'subject07_23_nonEx.csv',
#  'subject07_24_nonEx.csv',
#  'subject07_25_nonEx.csv',
#  'subject07_26_nonEx.csv',
#  'subject07_27_nonEx.csv',
#  'subject07_28_nonEx.csv',
#  'subject07_29_nonEx.csv',
#  'subject07_30_nonEx.csv',
#  'subject08_00_nonEx.csv',
#  'subject08_01_nonEx.csv',
#  'subject08_02_nonEx.csv',
#  'subject08_03_nonEx.csv',
#  'subject08_04_nonEx.csv',
#  'subject08_05_nonEx.csv',
#  'subject08_06_nonEx.csv',
#  'subject08_07_nonEx.csv',
#  'subject08_08_nonEx.csv',
#  'subject08_09_nonEx.csv',
#  'subject08_10_nonEx.csv',
#  'subject08_11_nonEx.csv',
#  'subject08_12_nonEx.csv',
#  'subject08_13_nonEx.csv',
#  'subject08_14_nonEx.csv',
#  'subject08_15_nonEx.csv',
#  'subject08_16_nonEx.csv',
#  'subject08_17_nonEx.csv',
#  'subject08_18_nonEx.csv',
#  'subject08_19_nonEx.csv',
#  'subject08_20_nonEx.csv',
#  'subject08_21_nonEx.csv',
#  'subject08_22_nonEx.csv',
#  'subject08_23_nonEx.csv',
#  'subject08_24_nonEx.csv',
#  'subject08_25_nonEx.csv',
#  'subject08_26_nonEx.csv',
#  'subject08_27_nonEx.csv',
#  'subject08_28_nonEx.csv',
#  'subject08_29_nonEx.csv',
#  'subject08_30_nonEx.csv',
#  'subject09_00_nonEx.csv',
#  'subject09_01_nonEx.csv',
#  'subject09_02_nonEx.csv',
#  'subject09_03_nonEx.csv',
#  'subject09_04_nonEx.csv',
#  'subject09_05_nonEx.csv',
#  'subject09_06_nonEx.csv',
#  'subject09_07_nonEx.csv',
#  'subject09_08_nonEx.csv',
#  'subject09_09_nonEx.csv',
#  'subject09_10_nonEx.csv',
#  'subject09_11_nonEx.csv',
#  'subject09_12_nonEx.csv',
#  'subject09_13_nonEx.csv',
#  'subject09_14_nonEx.csv',
#  'subject09_15_nonEx.csv',
#  'subject09_16_nonEx.csv',
#  'subject09_17_nonEx.csv',
#  'subject09_18_nonEx.csv',
#  'subject09_19_nonEx.csv',
#  'subject09_20_nonEx.csv',
#  'subject09_21_nonEx.csv',
#  'subject09_22_nonEx.csv',
#  'subject09_23_nonEx.csv',
#  'subject09_24_nonEx.csv',
#  'subject09_25_nonEx.csv',
#  'subject09_26_nonEx.csv',
#  'subject09_27_nonEx.csv',
#  'subject09_28_nonEx.csv',
#  'subject09_29_nonEx.csv',
#  'subject09_30_nonEx.csv']

# %% [markdown]
# ## What we know about the exercise data
#
# The repetitions of the different exercises have a duration mean of appr. 2.8 s with a standard deviation of 0.6 s (see Creating_Database_using_sqlite.ipynb).
#
# Hence, in the following cells the non-exercise data from the csv-files are split with the same mean and standard deviation. As an additional constraint, the split time ranges must have a length between 1 s and 5 s.
#
# The start and stop times of the generated time ranges are saved then to a database.

# %%
# defining the mean duration
dur_mean = 2.8 # [s]

# defining the standard deviation of the duration
dur_std = 0.6 # [s]

min_dur = 1 # [s]
max_dur = 5 # [s]

# %%
np.random.normal(loc=dur_mean, scale=dur_std)
# Out:
# 2.6843390173828787

# %% [markdown]
# ## Split non-exercise files and write times to database

# %%
# !!! Execute this code only once --> writing to database !!!

# connect with existing database
db_name = 'DataBase_Physio.db'
conn = sqlite3.connect(db_name)
cur = conn.cursor()

# create a new entry for non-exercise data in the paradigm table
paradigm_sql = 'INSERT INTO paradigms (abbreviation) VALUES (?)'
abbr_nonEx = 'NE' # abbreviation for non exercise data
cur.execute(paradigm_sql, (abbr_nonEx,))

# get the paradigm-id of non-exercise data
paradigm_sql = 'SELECT id FROM paradigms WHERE abbreviation = ?'
cur.execute(paradigm_sql, (abbr_nonEx,))
paradigm_id = cur.fetchone()[0]


# going through all non-exercise files
for ii in range(len(nonEx_files)):
    
    # get subject ID from filename
    subject_id = int(re.split('[t_.]',nonEx_files[ii])[1])
    
    # generate the entry in "exercises", and get the corresponding id
    number_repetitions = 0 # because it is not exercise data
    exercise_sql = 'INSERT INTO exercises (subject_id, paradigm_id, num_rep, csv_file) VALUES (?,?,?,?)'
    cur.execute(exercise_sql, (subject_id, paradigm_id, number_repetitions, nonEx_files[ii]))
    exercise_id = cur.lastrowid
    
    # join path to current csv-file
    nonEx_csv_path = os.path.join(file_dir, nonEx_files[ii])

    # load the signal data
    data = fmpm.get_sensor_data(nonEx_csv_path, signals=['Acc','Gyr','Mag'], sampling_rate=256)
    
    # get total duration of loaded signals in seconds
    signal_total_dur = data['time'][-1]

    # split the signals into blocks, considering the mean duration and standard deviation
    # of the exercise data --> generating randomized time ranges from 1 s to 5 s
    # --> if time is out of range, check if the last block is longer than
    # one second and take it, otherwise omit the last block
    start_time = 0 # [s] first start time is always zero
    block_sequence_number = 1 # sequence number for database
    # generate the entry in "repetitions" --> sequence number of the differt block used now
    repetitions_sql = 'INSERT INTO repetitions (sequence_num, exercise_id, start_time, stop_time) VALUES (?,?,?,?)'
    end_of_signal = False
    while end_of_signal is False:
        current_block_length = np.random.normal(loc=dur_mean, scale=dur_std) # [s]
        if current_block_length < min_dur:
            current_block_length = min_dur
        elif current_block_length > max_dur:
            current_block_length = max_dur
        stop_time = start_time + current_block_length

        # check if stop time is out of range
        if stop_time > signal_total_dur:
            end_of_signal = True
            # check if remaining block is longer than min_dur (1 s)
            if signal_total_dur-start_time > min_dur:
                stop_time = signal_total_dur # set stop time to total signal duration
            else:
                break # omit the remaining last block
        
        # write start and stop times to database (with additional required entries)
        cur.execute(repetitions_sql, (block_sequence_number, exercise_id, start_time, stop_time))
        
        block_sequence_number += 1 # increase sequence number of block
        start_time = stop_time # set start time for next run

conn.commit()
conn.close()

# %% [markdown]
# ## Show content of database

# %%
# Connect to the existing database (already renamed)
db_name = 'DataBase_Physio_with_nonEx.db'
conn = sqlite3.connect(db_name)
cur = conn.cursor()

# extract the data from the database
query_sql = """
    SELECT e.subject_id,
        p.abbreviation,
        e.num_rep,
        r.sequence_num,
        r.start_time, r.stop_time,
        e.csv_file
    FROM subjects s
    INNER JOIN exercises e
    ON s.id = e.subject_id
    INNER JOIN paradigms p
    ON p.id = e.paradigm_id
    INNER JOIN repetitions r
    ON e.id = r.exercise_id
    """
df = pd.read_sql_query(query_sql, conn)
conn.close()
df
# Out:
#       subject_id abbreviation  num_rep  sequence_num           start_time  \
# 0              1           RF        5             1   1.1482924107142871
# 1              1           RF        5             2    3.699122023809525
# 2              1           RF        5             3     6.49581473214286
# 3              1           RF        5             4    9.384706101190478
# 4              1           RF        5             5   12.073833705357146
# 5              2           RF        5             1   0.6509139384920637
# 6              2           RF        5             2    3.911928323412699
# 7              2           RF        5             3    7.031159474206351
# 8              2           RF        5             4   10.398511284722224
# 9              2           RF        5             5   13.588634052579367
# 10             3           RF        5             1   1.0330865575396828
# 11             3           RF        5             2   5.0426711309523835
# 12             3           RF        5             3    9.073030753968258
# 13             3           RF        5             4   13.020290178571432
# 14             3           RF        5             5   17.216850198412704
# 15             4           RF        5             1    1.492857142857142
# 16             4           RF        5             2    5.161269841269842
# 17             4           RF        5             3    8.656825396825397
# 18             4           RF        5             4    12.22920634920635
# 19             4           RF        5             5   15.379047619047622
# 20             5           RF        5             1   1.4544810267857144
# 21             5           RF        5             2    4.407661830357142
# 22             5           RF        5             3    7.673532366071429
# 23             5           RF        5             4   10.835172991071428
# 24             5           RF        5             5         14.083671875
# 25             7           RF        5             1  0.20373015873015987
# 26             7           RF        5             2   2.5041269841269864
# 27             7           RF        5             3    5.220079365079367
# 28             7           RF        5             4     7.78761904761905
# 29             7           RF        5             5   10.280952380952385
# ...          ...          ...      ...           ...                  ...
# 6799           9           NE        0             7     17.8875468001881
# 6800           9           NE        0             8      20.130022486765
# 6801           9           NE        0             9     22.4144491642536
# 6802           9           NE        0            10      24.887960845572
# 6803           9           NE        0             1                    0
# 6804           9           NE        0             2     3.05096196785543
# 6805           9           NE        0             3     6.85151481522579
# 6806           9           NE        0             4     9.77484676706946
# 6807           9           NE        0             5     11.3599619083279
# 6808           9           NE        0             6      14.168363651735
# 6809           9           NE        0             1                    0
# 6810           9           NE        0             2     2.95910635041716
# 6811           9           NE        0             3     5.98387387173255
# 6812           9           NE        0             4     8.97071118815999
# 6813           9           NE        0             5     11.5886136750582
# 6814           9           NE        0             6     14.4372796496611
# 6815           9           NE        0             7     18.2110942328794
# 6816           9           NE        0             8     20.9796919458863
# 6817           9           NE        0             9     24.0496882206178
# 6818           9           NE        0            10     26.3138324537659
# 6819           9           NE        0            11     29.4127538882356
# 6820           9           NE        0            12     31.7983605770392
# 6821           9           NE        0            13     36.1248043778777
# 6822           9           NE        0            14     38.6006380941706
# 6823           9           NE        0            15     40.9823975863704
# 6824           9           NE        0            16     43.9711165676531
# 6825           9           NE        0            17     46.9297260855027
# 6826           9           NE        0            18     49.7717292866719
# 6827           9           NE        0            19     53.8221753090678
# 6828           9           NE        0            20     57.3273715489712
#
#                stop_time                csv_file
# 0      3.699122023809525     subject01_RF_05.csv
# 1       6.49581473214286     subject01_RF_05.csv
# 2      9.384706101190478     subject01_RF_05.csv
# 3     12.073833705357146     subject01_RF_05.csv
# 4     14.809060639880954     subject01_RF_05.csv
# 5      3.911928323412699     subject02_RF_05.csv
# 6      7.031159474206351     subject02_RF_05.csv
# 7     10.398511284722224     subject02_RF_05.csv
# 8     13.588634052579367     subject02_RF_05.csv
# 9      16.49519035218254     subject02_RF_05.csv
# 10    5.0426711309523835     subject03_RF_05.csv
# 11     9.073030753968258     subject03_RF_05.csv
# 12    13.020290178571432     subject03_RF_05.csv
# 13    17.216850198412704     subject03_RF_05.csv
# 14    21.143334573412705     subject03_RF_05.csv
# 15     5.161269841269842     subject04_RF_05.csv
# 16     8.656825396825397     subject04_RF_05.csv
# 17     12.22920634920635     subject04_RF_05.csv
# 18    15.379047619047622     subject04_RF_05.csv
# 19    19.124285714285715     subject04_RF_05.csv
# 20     4.407661830357142     subject05_RF_05.csv
# 21     7.673532366071429     subject05_RF_05.csv
# 22    10.835172991071428     subject05_RF_05.csv
# 23          14.083671875     subject05_RF_05.csv
# 24     17.40165736607143     subject05_RF_05.csv
# 25    2.5041269841269864     subject07_RF_05.csv
# 26     5.220079365079367     subject07_RF_05.csv
# 27      7.78761904761905     subject07_RF_05.csv
# 28    10.280952380952385     subject07_RF_05.csv
# 29     12.80396825396826     subject07_RF_05.csv
# ...                  ...                     ...
# 6799     20.130022486765  subject09_28_nonEx.csv
# 6800    22.4144491642536  subject09_28_nonEx.csv
# 6801     24.887960845572  subject09_28_nonEx.csv
# 6802         27.19921875  subject09_28_nonEx.csv
# 6803    3.05096196785543  subject09_29_nonEx.csv
# 6804    6.85151481522579  subject09_29_nonEx.csv
# 6805    9.77484676706946  subject09_29_nonEx.csv
# 6806    11.3599619083279  subject09_29_nonEx.csv
# 6807     14.168363651735  subject09_29_nonEx.csv
# 6808    17.4130422860062  subject09_29_nonEx.csv
# 6809    2.95910635041716  subject09_30_nonEx.csv
# 6810    5.98387387173255  subject09_30_nonEx.csv
# 6811    8.97071118815999  subject09_30_nonEx.csv
# 6812    11.5886136750582  subject09_30_nonEx.csv
# 6813    14.4372796496611  subject09_30_nonEx.csv
# 6814    18.2110942328794  subject09_30_nonEx.csv
# 6815    20.9796919458863  subject09_30_nonEx.csv
# 6816    24.0496882206178  subject09_30_nonEx.csv
# 6817    26.3138324537659  subject09_30_nonEx.csv
# 6818    29.4127538882356  subject09_30_nonEx.csv
# 6819    31.7983605770392  subject09_30_nonEx.csv
# 6820    36.1248043778777  subject09_30_nonEx.csv
# 6821    38.6006380941706  subject09_30_nonEx.csv
# 6822    40.9823975863704  subject09_30_nonEx.csv
# 6823    43.9711165676531  subject09_30_nonEx.csv
# 6824    46.9297260855027  subject09_30_nonEx.csv
# 6825    49.7717292866719  subject09_30_nonEx.csv
# 6826    53.8221753090678  subject09_30_nonEx.csv
# 6827    57.3273715489712  subject09_30_nonEx.csv
# 6828         60.54296875  subject09_30_nonEx.csv
#
# [6829 rows x 7 columns]
