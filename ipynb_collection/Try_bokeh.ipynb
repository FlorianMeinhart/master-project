# %% [markdown]
# # Try bokeh

# %%
import pandas as pd
from bokeh.io import show, output_notebook
from bokeh.layouts import row, widgetbox
from bokeh.models import Select, TextInput
from bokeh.charts import Histogram
from bokeh.application.handlers import FunctionHandler
from bokeh.application import Application

from bokeh.models.widgets import Tabs, Panel
from bokeh.plotting import figure
from bokeh.layouts import layout
from bokeh.models import BoxSelectTool

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4b974c0c-6896-46e3-bea4-767b4628646c">Loading BokehJS ...</span>
#     </div>

# %%
iris_df = pd.read_csv("data/iris.data", 
    names=["Sepal Length", "Sepal Width", "Petal Length", "Petal Width", "Species"])
feature_names = iris_df.columns[0:-1].values.tolist()
iris_df.head()
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Create the Document Application
def modify_doc(doc):
    
    # Create the main plot
    def create_figure():
        current_feature_name = feature_name.value
        p = Histogram(iris_df, current_feature_name, title=current_feature_name, color='Species', 
            bins=20, legend='top_right', width=600, height=400)

        # Set the x axis label
        p.xaxis.axis_label = current_feature_name

        # Set the y axis label
        p.yaxis.axis_label = 'Count'
        return p

    # Update the plot
    def update(attr, old, new):
        layout.children[1] = create_figure()
        
    def my_text_input_handler(attr, old, new):
        #print("Previous label: " + old)
        #print("Updated label: " + new)
        feature_name.title = new
        layout.children[0] = widgetbox([text_input,feature_name], width=200)
        


    text_input = TextInput(value="default", title="Label:")
    text_input.on_change("value", my_text_input_handler)
    
    # Controls
    feature_name = Select(title="Iris Feature:", options=feature_names, value=feature_names[0])
    feature_name.on_change('value', update)
    controls = widgetbox([text_input,feature_name], width=200)
    p = create_figure()
    layout1 = row(controls, p)
    
    fig1 = figure()
    fig1.circle([0,1,2],[1,3,2])
    fig1.add_tools(BoxSelectTool())
    layout2 = layout([[fig1]],sizing_mode='fixed')
    
    tab1 = Panel(child=layout1,title="This is Tab 1")
    tab2 = Panel(child=layout2,title="This is Tab 2")
    tabs = Tabs(tabs=[ tab1, tab2 ])
    
    doc.add_root(tabs)

# Set up the Application 
handler = FunctionHandler(modify_doc)
app = Application(handler)

# %%
# Create the Document
# Not strictly necessary, but helps w/ debugging
doc = app.create_document()

# %%
# Show the application
# Make sure the URL matches your Jupyter instance
show(app, notebook_url="localhost:8888")
# Out:
# <div class='bokeh_class' id='0b1b7ff4aa3847f8a8ae74088049cbf1'>
# <script
#     src="http://127.0.0.1:50664/autoload.js?bokeh-autoload-element=72977fc0-322f-469d-9794-5c9754781822&bokeh-app-path=/&bokeh-absolute-url=http://127.0.0.1:50664"
#     id="72977fc0-322f-469d-9794-5c9754781822"
#     data-bokeh-model-id=""
#     data-bokeh-doc-id=""
# ></script></div>

# %%
dir(TextInput)
# Out:
# ['__cached_all__overridden_defaults__',
#  '__cached_all__properties__',
#  '__cached_all__properties_with_refs__',
#  '__class__',
#  '__container_props__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__properties__',
#  '__properties_with_refs__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__view_model__',
#  '__weakref__',
#  '_attach_document',
#  '_clone',
#  '_detach_document',
#  '_overridden_defaults',
#  '_repr_html_',
#  '_repr_pretty',
#  '_to_json_like',
#  '_trigger_event',
#  '_update_event_callbacks',
#  'apply_theme',
#  'callback',
#  'coerce_value',
#  'css_classes',
#  'dataspecs',
#  'dataspecs_with_props',
#  'disabled',
#  'document',
#  'equals',
#  'height',
#  'html',
#  'js_event_callbacks',
#  'js_on_change',
#  'js_on_event',
#  'js_property_callbacks',
#  'layout',
#  'lookup',
#  'name',
#  'on_change',
#  'on_event',
#  'placeholder',
#  'pprint',
#  'pretty',
#  'properties',
#  'properties_containers',
#  'properties_with_refs',
#  'properties_with_values',
#  'query_properties_with_values',
#  'ref',
#  'references',
#  'remove_on_change',
#  'select',
#  'select_one',
#  'set_from_json',
#  'set_select',
#  'sizing_mode',
#  'subscribed_events',
#  'tags',
#  'themed_values',
#  'title',
#  'to_json',
#  'to_json_string',
#  'trigger',
#  'unapply_theme',
#  'update',
#  'update_from_json',
#  'value',
#  'width']

# %%
dict(x=1,y=2,z=3)
# Out:
# {'x': 1, 'y': 2, 'z': 3}

# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f8efa3a1-e7e0-4b9e-aca8-357a57619fac">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.layouts import column
from bokeh.models.widgets import TextInput, Button, Paragraph

def modify_doc(doc):
    
    # create some widgets
    button = Button(label="Say HI")
    input = TextInput(value="Bokeh")
    output = Paragraph()

    # add a callback to a widget
    def update():
        output.text = "Hello, " + input.value
    button.on_click(update)

    # create a layout for everything
    layout = column(button, input, output)

    # add the layout to curdoc
    doc.add_root(layout)
    
# In the notebook, just pass the function that defines the app to show
# You may need to supply notebook_url, e.g notebook_url="http://localhost:8889" 
show(modify_doc, notebook_url="http://localhost:8888")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-1fe36241aa43> in <module>()
#      22 # In the notebook, just pass the function that defines the app to show
#      23 # You may need to supply notebook_url, e.g notebook_url="http://localhost:8889"
# ---> 24 show(modify_doc, notebook_url="http://localhost:8888")
#
# E:\Programme\WinPython-64bit-3.6.2.0Qt5\python-3.6.2.amd64\lib\site-packages\bokeh\io.py in show(obj, browser, new, notebook_handle, notebook_url)
#     285
#     286     if obj not in _state.document.roots:
# --> 287         _state.document.add_root(obj)
#     288     return _show_with_state(obj, _state, browser, new, notebook_handle=notebook_handle)
#     289
#
# E:\Programme\WinPython-64bit-3.6.2.0Qt5\python-3.6.2.amd64\lib\site-packages\bokeh\document.py in add_root(self, model, setter)
#     278             self._roots.append(model)
#     279         finally:
# --> 280             self._pop_all_models_freeze()
#     281         self._trigger_on_change(RootAddedEvent(self, model, setter))
#     282
#
# E:\Programme\WinPython-64bit-3.6.2.0Qt5\python-3.6.2.amd64\lib\site-packages\bokeh\document.py in _pop_all_models_freeze(self)
#    1081         self._all_models_freeze_count -= 1
#    1082         if self._all_models_freeze_count == 0:
# -> 1083             self._recompute_all_models()
#    1084
#    1085     def _recompute_all_models(self):
#
# E:\Programme\WinPython-64bit-3.6.2.0Qt5\python-3.6.2.amd64\lib\site-packages\bokeh\document.py in _recompute_all_models(self)
#    1089         new_all_models_set = set()
#    1090         for r in self.roots:
# -> 1091             new_all_models_set = new_all_models_set.union(r.references())
#    1092         old_all_models_set = set(self._all_models.values())
#    1093         to_detach = old_all_models_set - new_all_models_set
#
# AttributeError: 'function' object has no attribute 'references'

# %%
from random import random

from bokeh.layouts import column
from bokeh.models import Button
from bokeh.palettes import RdYlBu3
from bokeh.plotting import figure, curdoc

# create a plot and style its properties
p = figure(x_range=(0, 100), y_range=(0, 100), toolbar_location=None)
p.border_fill_color = 'black'
p.background_fill_color = 'black'
p.outline_line_color = None
p.grid.grid_line_color = None

# add a text renderer to our plot (no data yet)
r = p.text(x=[], y=[], text=[], text_color=[], text_font_size="20pt",
           text_baseline="middle", text_align="center")

i = 0

ds = r.data_source

# create a callback that will add a number in a random location
def callback():
    global i

    # BEST PRACTICE --- update .data in one step with a new dict
    new_data = dict()
    new_data['x'] = ds.data['x'] + [random()*70 + 15]
    new_data['y'] = ds.data['y'] + [random()*70 + 15]
    new_data['text_color'] = ds.data['text_color'] + [RdYlBu3[i%3]]
    new_data['text'] = ds.data['text'] + [str(i)]
    ds.data = new_data

    i = i + 1

# add a button widget and configure with the call back
button = Button(label="Press Me")
button.on_click(callback)

# put the button and plot in a layout and add to the document
curdoc().add_root(column(button, p))

# %%
from ipywidgets import interact
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()

x = np.linspace(0, 2*np.pi, 2000)
y = np.sin(x)

p = figure(title="simple line example", plot_height=300, plot_width=600, y_range=(-5,5),
           background_fill_color='#efefef')

p.title.text_font_size = '16pt'

r = p.line(x, y, color="#8888cc", line_width=1.5, alpha=0.8)

def update(fct, w=1, A=1, phi=0):
    if   fct == "sin": func = np.sin
    elif fct == "cos": func = np.cos
    r.data_source.data['y'] = A * func(w * x + phi)
    push_notebook()
    
show(p, notebook_handle=True)

interact(update, fct=["sin", "cos"], w=(0,50), A=(1,10), phi=(0, 20, 0.1));
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3dff0bb0-fbe2-4a9c-8e4e-aa5e77bb8390">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2d35c00e-7c12-46d2-a476-a714b2052c0c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2d35c00e-7c12-46d2-a476-a714b2052c0c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("d5bff69d-8d3c-4a4d-8ac2-7c97de69bb1f", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2d35c00e-7c12-46d2-a476-a714b2052c0c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2d35c00e-7c12-46d2-a476-a714b2052c0c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"18190b86-288a-4de0-9b34-fabbc0dbc7e5":{"roots":{"references":[{"attributes":{"formatter":{"id":"7981958a-125f-4f07-9516-aa73f3cecdf7","type":"BasicTickFormatter"},"plot":{"id":"1528e68f-d6cc-4b68-ad9a-f61ccdeed539","subtype":"Figure","type":"Plot"},"ticker":{"id":"5a5042ab-aa52-480c-91f2-dd3a5753fd84","type":"BasicTicker"}},"id":"f17473ad-095d-4b36-a6a0-6e0345b91d5b","type":"LinearAxis"},{"attributes":{},"id":"ce75eb2e-8ca4-4b78-9296-8ed894818ec3","type":"BasicTicker"},{"attributes":{},"id":"5a5042ab-aa52-480c-91f2-dd3a5753fd84","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":1.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"8d263678-3cff-4840-9f0b-a22511a5e5a6","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[2000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[2000]}}},"id":"cca368cd-d925-404b-912b-a7f9471fe6ec","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"e96c39c3-a87d-4f24-acc8-782e2537f3e2","type":"BasicTickFormatter"},"plot":{"id":"1528e68f-d6cc-4b68-ad9a-f61ccdeed539","subtype":"Figure","type":"Plot"},"ticker":{"id":"ce75eb2e-8ca4-4b78-9296-8ed894818ec3","type":"BasicTicker"}},"id":"4e2b5342-e8fe-4e63-b931-38cdfca410f7","type":"LinearAxis"},{"attributes":{"plot":{"id":"1528e68f-d6cc-4b68-ad9a-f61ccdeed539","subtype":"Figure","type":"Plot"}},"id":"640afaf3-ac4a-459d-8feb-72292581c65a","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"1528e68f-d6cc-4b68-ad9a-f61ccdeed539","subtype":"Figure","type":"Plot"},"ticker":{"id":"5a5042ab-aa52-480c-91f2-dd3a5753fd84","type":"BasicTicker"}},"id":"1544ac45-68f8-41b8-b057-3eaafe8a291a","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"63c44624-55a0-4db5-8c89-78b437445a47","type":"BoxAnnotation"},{"attributes":{"background_fill_color":{"value":"#efefef"},"below":[{"id":"4e2b5342-e8fe-4e63-b931-38cdfca410f7","type":"LinearAxis"}],"left":[{"id":"f17473ad-095d-4b36-a6a0-6e0345b91d5b","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":
type":"BasicTickFormatter"},{"attributes":{"label":{"value":"Temp."},"renderers":[{"id":"0ad95087-033c-4522-8f0f-c5c11aa3cd9c","type":"GlyphRenderer"}]},"id":"a320989b-f540-46ad-b231-80b9de93df4a","type":"LegendItem"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e5a62418-748d-4958-bfee-9eab43bcf15c","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"4275d31a-c033-446a-985d-df6ccfa219de","subtype":"Figure","type":"Plot"},"ticker":{"id":"cafa9657-4637-43e7-a487-50b43145ec04","type":"BasicTicker"}},"id":"f83d4cfd-31f9-48c4-925e-aab6c4faff9c","type":"Grid"},{"attributes":{"below":[{"id":"1f9d96e4-8f74-483e-94fa-9493e9ea26da","type":"LinearAxis"}],"left":[{"id":"efe3a831-c685-431a-a8f0-b2d5708b5226","type":"LinearAxis"}],"renderers":[{"id":"1f9d96e4-8f74-483e-94fa-9493e9ea26da","type":"LinearAxis"},{"id":"a938ccc8-1edb-43dc-a8a9-fe59dbb2c97b","type":"Grid"},{"id":"efe3a831-c685-431a-a8f0-b2d5708b5226","type":"LinearAxis"},{"id":"f83d4cfd-31f9-48c4-925e-aab6c4faff9c","type":"Grid"},{"id":"e5a62418-748d-4958-bfee-9eab43bcf15c","type":"BoxAnnotation"},{"id":"9f3be669-901a-4470-9559-67971b6e8fcd","type":"Legend"},{"id":"0ad95087-033c-4522-8f0f-c5c11aa3cd9c","type":"GlyphRenderer"}],"title":{"id":"71f8f3eb-0273-42fd-824b-bd2857693274","type":"Title"},"tool_events":{"id":"5a2de9dc-01e6-4910-8da8-536589388f6e","type":"ToolEvents"},"toolbar":{"id":"247d39c6-23f1-4997-99cb-e07209ca7e9e","type":"Toolbar"},"x_range":{"id":"1db7599a-dc50-45d6-a4fd-181d3d9d0f25","type":"DataRange1d"},"x_scale":{"id":"67e450c0-68ce-4af2-a8f9-aac822380a01","type":"LinearScale"},"y_range":{"id":"b236ad5f-7c85-45e1-ad56-fc58be36fd9a","type":"DataRange1d"},"y_scale":{"id":"5f5b927e-8c17-4714-8a90-7873959a1f1c","type":"LinearScale"}},"id":"4275d31a-c033-446a-985d-df6ccfa219de","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"b236ad5f-7c85-45e1-ad56-fc58be36fd9a","type":"DataRange1d"},{"attributes":{"plot":{"id":"4275d31a-c033-446a-985d-df6ccfa219de","subtype":"Figure","type":"Plot"}},"id":"1c1e04b3-06d9-4f67-8c0f-fd003c6e77e6","type":"SaveTool"},{"attributes":{"plot":{"id":"4275d31a-c033-446a-985d-df6ccfa219de","subtype":"Figure","type":"Plot"}},"id":"e9ecb983-f565-432e-9032-5ce7e55a9759","type":"ResetTool"},{"attributes":{"plot":{"id":"4275d31a-c033-446a-985d-df6ccfa219de","subtype":"Figure","type":"Plot"}},"id":"ccfa9803-3bb5-49c9-b26b-f71c389f1e77","type":"PanTool"},{"attributes":{"items":[{"id":"a320989b-f540-46ad-b231-80b9de93df4a","type":"LegendItem"}],"plot":{"id":"4275d31a-c033-446a-985d-df6ccfa219de","subtype":"Figure","type":"Plot"}},"id":"9f3be669-901a-4470-9559- ...
